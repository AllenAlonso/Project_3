# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress

file_path = "data_unclean/2018.csv"
df_cleaned = pd.read_csv(file_path)
df_cleaned
# Out:
#      Unnamed: 0    Unnamed: 1    year   rnd    ovl     phase      player name  \
# 0             0           NaN  2018.0   1.0    1.0  June-Reg       Casey Mize
# 1             1           NaN  2018.0   1.0    2.0  June-Reg        Joey Bart
# 2             2           NaN  2018.0   1.0    3.0  June-Reg        Alec Bohm
# 3             3           NaN  2018.0   1.0    4.0  June-Reg    Nick Madrigal
# 4             4           NaN  2018.0   1.0    5.0  June-Reg   Jonathan India
# ..          ...           ...     ...   ...    ...       ...              ...
# 319          26           NaN  2018.0  10.0  311.0  June-Reg    Carson Shaddy
# 320          27           NaN  2018.0  10.0  312.0  June-Reg  Chandler Taylor
# 321          28           NaN  2018.0  10.0  313.0  June-Reg     Robert Broom
# 322          29           NaN  2018.0  10.0  314.0  June-Reg     Deacon Liput
# 323          30  30 record(s)     NaN   NaN    NaN       NaN              NaN
#
#                   draft team  pos  bonus  ...   source         school dr reg  \
# 0             Detroit Tigers    p   7.50  ...  College         Auburn     AL
# 1       San Francisco Giants    c   7.03  ...  College   Georgia Tech     GA
# 2      Philadelphia Phillies   3b   5.85  ...  College  Wichita State     KS
# 3          Chicago White Sox   ss   6.41  ...  College   Oregon State     OR
# 4            Cincinnati Reds   3b   5.30  ...  College        Florida     FL
# ..                       ...  ...    ...  ...      ...            ...    ...
# 319     Washington Nationals   2b   0.01  ...  College       Arkansas     AR
# 320           Houston Astros   lf   0.07  ...  College        Alabama     AL
# 321  Cleveland Baseball Team    p   0.14  ...  College         Mercer     GA
# 322      Los Angeles Dodgers   2b   0.13  ...  College        Florida     FL
# 323                      NaN  NaN    NaN  ...      NaN            NaN    NaN
#
#      pos.1    ht     wt   ba   th        Born            place
# 0        p   6-3  212.0    R    R  1997-05-01   Springville,AL
# 1        c   6-2  238.0    R    R  1996-12-15        Buford,GA
# 2       3b   6-5  218.0    R    R  1996-08-03         Omaha,NE
# 3       2b   5-8  175.0    R    R  1997-03-05     Elk Grove,CA
# 4       2b   6-0  185.0    R    R  1996-12-15    Plantation,FL
# ..     ...   ...    ...  ...  ...         ...              ...
# 319     2b  5-11  185.0    R    R  1994-08-19  Fayetteville,AR
# 320  rf-cf   6-1  210.0    L    L  1996-02-07    Montgomery,AL
# 321      p   6-1  190.0    R    R  1996-09-17    East Ridge,TN
# 322  2b-3b  5-10  185.0    L    R  1996-06-27        Oviedo,FL
# 323    NaN   NaN    NaN  NaN  NaN         NaN              NaN
#
# [324 rows x 24 columns]

# %%
df = pd.read_csv("data_unclean/2018.csv")

# %%
selected_columns = ['player name', 'school', 'source', 'hilvl']
df_cleaned = df[selected_columns]

# %%
df_cleaned.columns = ['Player Name', 'School', 'Source', 'High Level']

# %%
df_cleaned = df_cleaned.dropna(subset=['Player Name', 'School', 'Source', 'High Level'])

# %%
df_cleaned = df_cleaned.reset_index(drop=True)

# %%
print(df_cleaned)
# Out:
#          Player Name          School   Source High Level
# 0         Casey Mize          Auburn  College        MLB
# 1          Joey Bart    Georgia Tech  College        MLB
# 2          Alec Bohm   Wichita State  College        MLB
# 3      Nick Madrigal    Oregon State  College        MLB
# 4     Jonathan India         Florida  College        MLB
# ..               ...             ...      ...        ...
# 309   Grant Williams  Kennesaw State  College        AAA
# 310    Carson Shaddy        Arkansas  College         A-
# 311  Chandler Taylor         Alabama  College        AAA
# 312     Robert Broom          Mercer  College        AAA
# 313     Deacon Liput         Florida  College        AAA
#
# [314 rows x 4 columns]
