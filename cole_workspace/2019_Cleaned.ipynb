# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress

file_path = "data_unclean/2019.csv"
df_cleaned = pd.read_csv(file_path)
df_cleaned
# Out:
#      Unnamed: 0    Unnamed: 1    year   rnd    ovl     phase      player name  \
# 0             0           NaN  2019.0   1.0    1.0  June-Reg  Adley Rutschman
# 1             1           NaN  2019.0   1.0    2.0  June-Reg       Bobby Witt
# 2             2           NaN  2019.0   1.0    3.0  June-Reg    Andrew Vaughn
# 3             3           NaN  2019.0   1.0    4.0  June-Reg        JJ Bleday
# 4             4           NaN  2019.0   1.0    5.0  June-Reg     Riley Greene
# ..          ...           ...     ...   ...    ...       ...              ...
# 322          26           NaN  2019.0  10.0  314.0  June-Reg   Patrick McColl
# 323          27           NaN  2019.0  10.0  315.0  June-Reg     Mitch Spence
# 324          28           NaN  2019.0  10.0  316.0  June-Reg      C.J. Stubbs
# 325          29           NaN  2019.0  10.0  317.0  June-Reg    Stephen Scott
# 326          30  30 record(s)     NaN   NaN    NaN       NaN              NaN
#
#              draft team  pos  bonus  ...   source  \
# 0     Baltimore Orioles    c   8.10  ...  College
# 1    Kansas City Royals   ss   7.79  ...       HS
# 2     Chicago White Sox   1b   7.22  ...  College
# 3         Miami Marlins   of   6.67  ...  College
# 4        Detroit Tigers   of   6.18  ...       HS
# ..                  ...  ...    ...  ...      ...
# 322   Oakland Athletics   1b   0.02  ...  College
# 323    New York Yankees    p   0.12  ...  College
# 324      Houston Astros    c   0.09  ...  College
# 325      Boston Red Sox   of   0.05  ...  College
# 326                 NaN  NaN    NaN  ...      NaN
#
#                                     school dr reg  pos.1    ht     wt   ba  \
# 0                             Oregon State     OR   c-dh   6-2  230.0    B
# 1    Colleyville Heritage (Colleyville,TX)     TX  ss-3b   6-1  200.0    R
# 2                               California     CA  rf-lf   6-0  215.0    R
# 3                               Vanderbilt     TN  cf-lf   6-3  205.0    L
# 4                      Hagerty (Oviedo,FL)     FL     cf   6-3  200.0    L
# ..                                     ...    ...    ...   ...    ...  ...
# 322                                Harvard     MA  1b-lf   6-6  215.0    L
# 323                              USC Aiken     SC      p   6-1  185.0    R
# 324                                    USC     CA   c-1b   6-3  207.0    R
# 325                             Vanderbilt     TN      c  5-11  207.0    L
# 326                                    NaN    NaN    NaN   NaN    NaN  NaN
#
#       th        Born           place
# 0      R  1998-02-06     Portland,OR
# 1      R  2000-06-14  Colleyville,TX
# 2      R  1998-04-03   Santa Rosa,CA
# 3      L  1997-11-10     Danville,PA
# 4      L  2000-09-28      Orlando,FL
# ..   ...         ...             ...
# 322    R  1997-06-22    Los Altos,CA
# 323    R  1998-05-06     Kirkland,WA
# 324    R  1996-11-12    San Diego,CA
# 325    R  1997-05-23      Raleigh,NC
# 326  NaN         NaN             NaN
#
# [327 rows x 24 columns]

# %%
df = pd.read_csv("data_unclean/2019.csv")

# %%
selected_columns = ['player name', 'school', 'source', 'hilvl']
df_cleaned = df[selected_columns]

# %%
df_cleaned.columns = ['Player Name', 'School', 'Source', 'High Level']

# %%
df_cleaned = df_cleaned.dropna(subset=['Player Name', 'School', 'Source', 'High Level'])

# %%
df_cleaned = df_cleaned.reset_index(drop=True)

# %%
print(df_cleaned)
# Out:
#          Player Name                                 School   Source  \
# 0    Adley Rutschman                           Oregon State  College
# 1         Bobby Witt  Colleyville Heritage (Colleyville,TX)       HS
# 2      Andrew Vaughn                             California  College
# 3          JJ Bleday                             Vanderbilt  College
# 4       Riley Greene                    Hagerty (Oviedo,FL)       HS
# ..               ...                                    ...      ...
# 312     Taylor Floyd                             Texas Tech  College
# 313   Patrick McColl                                Harvard  College
# 314     Mitch Spence                              USC Aiken  College
# 315      C.J. Stubbs                                    USC  College
# 316    Stephen Scott                             Vanderbilt  College
#
#     High Level
# 0          MLB
# 1          MLB
# 2          MLB
# 3          MLB
# 4          MLB
# ..         ...
# 312         AA
# 313         A+
# 314        AAA
# 315         AA
# 316         AA
#
# [317 rows x 4 columns]
