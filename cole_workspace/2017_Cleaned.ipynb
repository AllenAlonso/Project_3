# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress

file_path = "data_unclean/2017.csv"
df_cleaned = pd.read_csv(file_path)
df_cleaned
# Out:
#      Unnamed: 0    Unnamed: 1    year   rnd    ovl     phase     player name  \
# 0             0           NaN  2017.0   1.0    1.0  June-Reg     Royce Lewis
# 1             1           NaN  2017.0   1.0    2.0  June-Reg   Hunter Greene
# 2             2           NaN  2017.0   1.0    3.0  June-Reg  MacKenzie Gore
# 3             3           NaN  2017.0   1.0    4.0  June-Reg   Brendan McKay
# 4             4           NaN  2017.0   1.0    5.0  June-Reg     Kyle Wright
# ..          ...           ...     ...   ...    ...       ...             ...
# 319          25           NaN  2017.0  10.0  312.0  June-Reg   Jesse Berardi
# 320          26           NaN  2017.0  10.0  313.0  June-Reg     Trey Turner
# 321          27           NaN  2017.0  10.0  314.0  June-Reg       John King
# 322          28           NaN  2017.0  10.0  315.0  June-Reg  Brian Glowicki
# 323          29  29 record(s)     NaN   NaN    NaN       NaN             NaN
#
#                   draft team  pos  bonus  ...   source  \
# 0            Minnesota Twins   ss   6.73  ...       HS
# 1            Cincinnati Reds    p   7.23  ...       HS
# 2           San Diego Padres    p   6.70  ...       HS
# 3             Tampa Bay Rays   1b   7.01  ...  College
# 4             Atlanta Braves    p   7.00  ...  College
# ..                       ...  ...    ...  ...      ...
# 319  Cleveland Baseball Team   ss   0.13  ...  College
# 320     Washington Nationals    p   0.10  ...  College
# 321            Texas Rangers    p   0.01  ...  College
# 322             Chicago Cubs    p   0.01  ...  College
# 323                      NaN  NaN    NaN  ...      NaN
#
#                                        school dr reg pos.1    ht     wt   ba  \
# 0    JSerra Catholic (San Juan Capistrano,CA)     CA    ss   6-2  200.0    R
# 1                Notre Dame (Sherman Oaks,CA)     CA     p   6-5  242.0    R
# 2                  Whiteville (Whiteville,NC)     NC     p   6-2  192.0    L
# 3                                  Louisville     KY     p   6-2  220.0    L
# 4                                  Vanderbilt     TN     p   6-4  215.0    R
# ..                                        ...    ...   ...   ...    ...  ...
# 319                                St. John's     NY    ss  5-10  185.0    L
# 320                            Missouri State     MO     p   6-1  195.0    R
# 321                                   Houston     TX     p   6-2  215.0    L
# 322                                 Minnesota     MN     p   6-0  180.0    R
# 323                                       NaN    NaN   NaN   NaN    NaN  NaN
#
#       th        Born             place
# 0      R  1999-06-05    Aliso Viejo,CA
# 1      R  1999-08-06    Los Angeles,CA
# 2      L  1999-02-24     Wilmington,NC
# 3      L  1995-12-18     Darlington,PA
# 4      R  1995-10-02     Huntsville,AL
# ..   ...         ...               ...
# 319    R  1996-01-13        Commack,NY
# 320    R  1996-06-15     Fort Scott,KS
# 321    L  1994-09-14         Laredo,TX
# 322    R  1994-10-19  Downers Grove,IL
# 323  NaN         NaN               NaN
#
# [324 rows x 24 columns]

# %%
df = pd.read_csv("data_unclean/2017.csv")

# %%
selected_columns = ['player name', 'school', 'source', 'hilvl']
df_cleaned = df[selected_columns]

# %%
df_cleaned.columns = ['Player Name', 'School', 'Source', 'High Level']

# %%
df_cleaned = df_cleaned.dropna(subset=['Player Name', 'School', 'Source', 'High Level'])

# %%
df_cleaned = df_cleaned.reset_index(drop=True)

# %%
print(df_cleaned)
# Out:
#         Player Name                                    School   Source  \
# 0       Royce Lewis  JSerra Catholic (San Juan Capistrano,CA)       HS
# 1     Hunter Greene              Notre Dame (Sherman Oaks,CA)       HS
# 2    MacKenzie Gore                Whiteville (Whiteville,NC)       HS
# 3     Brendan McKay                                Louisville  College
# 4       Kyle Wright                                Vanderbilt  College
# ..              ...                                       ...      ...
# 309     Jordan Wren                          Georgia Southern  College
# 310   Jesse Berardi                                St. John's  College
# 311     Trey Turner                            Missouri State  College
# 312       John King                                   Houston  College
# 313  Brian Glowicki                                 Minnesota  College
#
#     High Level
# 0          MLB
# 1          MLB
# 2          MLB
# 3          MLB
# 4          MLB
# ..         ...
# 309         A+
# 310          A
# 311          A
# 312        MLB
# 313         AA
#
# [314 rows x 4 columns]
