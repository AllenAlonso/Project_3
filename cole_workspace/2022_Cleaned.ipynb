# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress

file_path = "data_unclean/2022.csv"
df_cleaned = pd.read_csv(file_path)
df_cleaned
# Out:
#      Unnamed: 0    Unnamed: 1    year   rnd    ovl     phase  \
# 0             0           NaN  2022.0   1.0    1.0  June-Reg
# 1             1           NaN  2022.0   1.0    2.0  June-Reg
# 2             2           NaN  2022.0   1.0    3.0  June-Reg
# 3             3           NaN  2022.0   1.0    4.0  June-Reg
# 4             4           NaN  2022.0   1.0    5.0  June-Reg
# ..          ...           ...     ...   ...    ...       ...
# 320          26           NaN  2022.0  10.0  313.0  June-Reg
# 321          27           NaN  2022.0  10.0  314.0  June-Reg
# 322          28           NaN  2022.0  10.0  315.0  June-Reg
# 323          29           NaN  2022.0  10.0  316.0  June-Reg
# 324          30  30 record(s)     NaN   NaN    NaN       NaN
#
#           player name            draft team  pos  bonus  ...   source  \
# 0    Jackson Holliday     Baltimore Orioles   ss   8.19  ...       HS
# 1          Druw Jones  Arizona Diamondbacks   of   8.19  ...       HS
# ...

# %%
df = pd.read_csv("data_unclean/2022.csv")

# %%
selected_columns = ['player name', 'school', 'source', 'hilvl']
df_cleaned = df[selected_columns]

# %%
df_cleaned.columns = ['Player Name', 'School', 'Source', 'High Level']

# %%
df_cleaned = df_cleaned.dropna(subset=['Player Name', 'School', 'Source', 'High Level'])

# %%
df_cleaned = df_cleaned.reset_index(drop=True)

# %%
print(df_cleaned)
# Out:
#            Player Name                             School   Source High Level
# 0     Jackson Holliday         Stillwater (Stillwater,OK)       HS         A+
# 1           Druw Jones  The Wesleyan School (Norcross,GA)       HS          A
# 2         Kumar Rocker                           New York       FA         A+
# 3      Termarr Johnson                  Mays (Atlanta,GA)       HS          A
# 4         Elijah Green         IMG Academy (Bradenton,FL)       HS          A
# ..                 ...                                ...      ...        ...
# 310  Brian Fitzpatrick                            Rutgers  College         Rk
# 311          Zach Cole                         Ball State  College          A
# 312      Cade Halemanu                             Hawaii  College          A
# 313         Simon Reid                   Westmont College  College         Rk
# 314      John Bertrand                         Notre Dame  College         A+
#
# [315 rows x 4 columns]
